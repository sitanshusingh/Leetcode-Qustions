# %% [markdown]
# ## Pattern Questions

# %% [markdown]
# #### Question 1 Right-Angled Triangle Pattern in Python

# %%
rows = int(input("Enter the rows size for the pattern:- "))
for i in range(1,rows+1):
    for j in range(1,i+1):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# #### Question 2 Inverted Right-Angled Triangle in Python

# %%
rows = int(input("Enter the rows size for the pattern:- "))
for i in range(rows,0,-1):
    for j in range(1,i+1):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %% [markdown]
# #### Question 3 Pyramid Pattern in Python

# %%
rows = int(input("Enter the rows size for the pattern:- "))
for i in range(1,rows+1):
    for j in range(rows-i):
        print(" ",end=" ")
    for k in range(1,2*i):
        print("*",end=" ")
    print()
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %% [markdown]
# #### Question 4 Inverted Pyramid Pattern in Python

# %%
rows = int(input("Enter the rows size for the pattern:- "))
for i in range(rows,0,-1):
    for j in range(rows-i):
        print(" ",end=" ")
    for k in range(1,2*i):
        print("*",end=" ")
    print()
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %% [markdown]
# #### Question 5 Diamond Pattern in Python

# %%
rows = int(input("Enter the rows size for the pattern:- "))
for i in range(1,rows+1):
    for j in range(rows-i):
        print(" ",end=" ")
    for k in range(1,2*i):
        print("*",end=" ")
    print()
for i in range(rows-1,0,-1):
    for j in range(rows-i):
        print(" ",end=" ")
    for k in range(1,2*i):
        print("*",end=" ")
    print()
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %% [markdown]
# #### Question 6 Hollow Square Pattern in Python Code:

# %%
rows = int(input("Enter the rows size for the pattern:- "))
